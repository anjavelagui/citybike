# %%
#import dependencies
import numpy as np
import csv
from bs4 import BeautifulSoup
import pandas as pd
import time
import datetime as dt
source_file = '201306-citibike-tripdata.csv'

# %%
citybike_df = pd.read_csv(source_file, encoding='utf-8', parse_dates=['starttime'])

citybike_df.head()
# Out:
#    tripduration           starttime       stoptime  start station id  \
# 0           695 2013-06-01 00:00:00  6/1/2013 0:11               444
# 1           693 2013-06-01 00:00:00  6/1/2013 0:11               444
# 2          2059 2013-06-01 00:00:00  6/1/2013 0:35               406
# 3           123 2013-06-01 00:01:00  6/1/2013 0:03               475
# 4          1521 2013-06-01 00:01:00  6/1/2013 0:26              2008
#
#        start station name  start station latitude  start station longitude  \
# 0      Broadway & W 24 St               40.742354               -73.989151
# 1      Broadway & W 24 St               40.742354               -73.989151
# 2  Hicks St & Montague St               40.695128               -73.995951
# 3     E 15 St & Irving Pl               40.735243               -73.987586
# 4   Little West St & 1 Pl               40.705693               -74.016777
#
#    end station id        end station name  end station latitude  \
# ...

# %%
citybike_df['starttime'] = pd.to_datetime(citybike_df['starttime'])
citybike_df['starttime'].head()
# Out:
# 0   2013-06-01 00:00:00
# 1   2013-06-01 00:00:00
# 2   2013-06-01 00:00:00
# 3   2013-06-01 00:01:00
# 4   2013-06-01 00:01:00
# Name: starttime, dtype: datetime64[ns]

# %%
citybike_df['stoptime'] = pd.to_datetime(citybike_df['stoptime'])
citybike_df['stoptime'].head()
# Out:
# 0   2013-06-01 00:11:00
# 1   2013-06-01 00:11:00
# 2   2013-06-01 00:35:00
# 3   2013-06-01 00:03:00
# 4   2013-06-01 00:26:00
# Name: stoptime, dtype: datetime64[ns]

# %%
cleancitybike_df=citybike_df[['starttime','stoptime', 'tripduration','start station id', 'start station name', 'start station latitude', 'start station longitude', 'end station id', 'end station id', 'end station name', 'end station latitude', 'end station longitude', 'birth year', 'gender']]
cleancitybike_df.head()
# Out:
#             starttime            stoptime  tripduration  start station id  \
# 0 2013-06-01 00:00:00 2013-06-01 00:11:00           695               444
# 1 2013-06-01 00:00:00 2013-06-01 00:11:00           693               444
# 2 2013-06-01 00:00:00 2013-06-01 00:35:00          2059               406
# 3 2013-06-01 00:01:00 2013-06-01 00:03:00           123               475
# 4 2013-06-01 00:01:00 2013-06-01 00:26:00          1521              2008
#
#        start station name  start station latitude  start station longitude  \
# 0      Broadway & W 24 St               40.742354               -73.989151
# 1      Broadway & W 24 St               40.742354               -73.989151
# 2  Hicks St & Montague St               40.695128               -73.995951
# 3     E 15 St & Irving Pl               40.735243               -73.987586
# 4   Little West St & 1 Pl               40.705693               -74.016777
#
#    end station id  end station id        end station name  \
# ...

# %%
newcitytest=citybike_df[0:100]
newcitytest
# Out:
#     tripduration           starttime            stoptime  start station id  \
# 0            695 2013-06-01 00:00:00 2013-06-01 00:11:00               444
# 1            693 2013-06-01 00:00:00 2013-06-01 00:11:00               444
# 2           2059 2013-06-01 00:00:00 2013-06-01 00:35:00               406
# 3            123 2013-06-01 00:01:00 2013-06-01 00:03:00               475
# 4           1521 2013-06-01 00:01:00 2013-06-01 00:26:00              2008
# ..           ...                 ...                 ...               ...
# 95          8299 2013-06-01 00:35:00 2013-06-01 02:54:00               481
# 96           357 2013-06-01 00:36:00 2013-06-01 00:41:00               439
# 97          2215 2013-06-01 00:37:00 2013-06-01 01:14:00               157
# 98           915 2013-06-01 00:37:00 2013-06-01 00:53:00               143
# 99          2184 2013-06-01 00:38:00 2013-06-01 01:14:00               157
#
#            start station name  start station latitude  \
# ...

# %%
cleancitybike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577703 entries, 0 to 577702
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                577703 non-null  datetime64[ns]
#  1   stoptime                 577703 non-null  datetime64[ns]
#  2   tripduration             577703 non-null  int64
#  3   start station id         577703 non-null  int64
#  4   start station name       577703 non-null  object
#  5   start station latitude   577703 non-null  float64
#  6   start station longitude  577703 non-null  float64
#  7   end station id           559644 non-null  float64
#  8   end station id           559644 non-null  float64
#  9   end station name         559644 non-null  object
#  10  end station latitude     559644 non-null  float64
#  11  end station longitude    559644 non-null  float64
#  12  birth year               337382 non-null  float64
# ...

# %%
cleancitybike_df['starttime': pd.date_range(6/1/2013, 6/7/2013)]
cleancitybike_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-7f68ead0e6b7> in <module>
# ----> 1 cleancitybike_df['starttime': pd.date_range(6/1/2013, 6/7/2013)]
#       2 cleancitybike_df.head()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2997
#    2998         # Do we have a slicer (on rows)?
# -> 2999         indexer = convert_to_index_sliceable(self, key)
#    3000         if indexer is not None:
#    3001             if isinstance(indexer, np.ndarray):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2208     idx = obj.index
#    2209     if isinstance(key, slice):
# -> 2210         return idx._convert_slice_indexer(key, kind="getitem")
#    2211
#    2212     elif isinstance(key, str):
#
# ...

# %%
cleancitybike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577703 entries, 0 to 577702
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                577703 non-null  datetime64[ns]
#  1   stoptime                 577703 non-null  datetime64[ns]
#  2   tripduration             577703 non-null  int64
#  3   start station id         577703 non-null  int64
#  4   start station name       577703 non-null  object
#  5   start station latitude   577703 non-null  float64
#  6   start station longitude  577703 non-null  float64
#  7   end station id           559644 non-null  float64
#  8   end station id           559644 non-null  float64
#  9   end station name         559644 non-null  object
#  10  end station latitude     559644 non-null  float64
#  11  end station longitude    559644 non-null  float64
#  12  birth year               337382 non-null  float64
# ...

# %%
cleancitybike_df.groupby(pd.Grouper(key='starttime',freq='7D')).sum()
# Out:
#             tripduration  start station id  start station latitude  \
# starttime
# 2013-06-01     180707615          34832592            3.153016e+06
# 2013-06-08     148857696          42498187            3.881249e+06
# 2013-06-15     189349103          70660901            6.487417e+06
# 2013-06-22     208546585          82070301            7.783050e+06
# 2013-06-29      65476969          23681835            2.226518e+06
#
#             start station longitude  end station id  end station id  \
# starttime
# 2013-06-01            -5.727570e+06      33788928.0      33788928.0
# 2013-06-08            -7.050400e+06      41497411.0      41497411.0
# 2013-06-15            -1.178454e+07      68915500.0      68915500.0
# 2013-06-22            -1.413787e+07      80016158.0      80016158.0
# 2013-06-29            -4.044590e+06      23094632.0      23094632.0
#
#             end station latitude  end station longitude   birth year  gender
# starttime
# ...

# %%
#Rename CSV
citybike_df.to_csv("citybike2weeks.csv", encoding="utf-8", index=False, header=True)

# %%
cleancitybike_df = pd.DataFrame({'starttime': pd.date_range('06/1/2013', periods=8, freq='7D')})
cleancitybike_df.head()
# Out:
#    starttime
# 0 2013-06-01
# 1 2013-06-08
# 2 2013-06-15
# 3 2013-06-22
# 4 2013-06-29
